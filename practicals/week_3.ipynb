# %% [markdown]
# # Preliminaries
#
# The `pandas` library allows the user several data structures for different data manipulation tasks:
# 1. Data storage through its `Series` and `DataFrame` data structures.
# 2. Data filtering using multiple methods from the package.
# 3. Reading data from many different file formats such as `csv`, `txt`, `xlsx`, ...
#
# Below we provide a brief overview of the `pandas` functionalities needed for these exercises. The complete documentation can be found on the [`pandas` website](https://pandas.pydata.org/).
#
# ## Pandas data structures
#
# ### Series
# The Pandas Series data structure is similar to a one-dimensional array. It can store any type of data. The values are mutable but the size not.
#
# To create `Series`, we call the `pd.Series()` method and pass an array. A `Series` may also be created from a numpy array.

# %%
import pandas as pd
import numpy as np

first_series = pd.Series([1,10,100,1000])

print(first_series)

teams = np.array(['PSV','Ajax','Feyenoord','Twente'])
second_series = pd.Series(teams)

print('\n')
print(second_series)
# Out:
# 0       1
# 1      10
# 2     100
# 3    1000
# dtype: int64
#
#
# 0          PSV
# 1         Ajax
# 2    Feyenoord
# 3       Twente
# dtype: object

# %% [markdown]
# ### DataFrame
# One can think of a `DataFrame` as a table with rows and columns (2D structure). The columns can be of a different type (as opposed to `numpy` arrays) and the size of the `DataFrame` is mutable.
#
# To create `DataFrame`, we call the `pd.DataFrame()` method and we can create it from scratch or we can convert a numpy array or a list into a `DataFrame`.

# %%
# DataFrame from scratch
first_dataframe = pd.DataFrame({
    "Position": [1, 2, 3, 4],
    "Team": ['PSV','Ajax','Feyenoord','Twente'],
    "GF": [80, 75, 75, 70],
    "GA": [30, 25, 40, 60],
    "Points": [79, 78, 70, 66]
})

print("From scratch: \n {} \n".format(first_dataframe))

# DataFrme from a list
data = [[1, 2, 3, 4], ['PSV','Ajax','Feyenoord','Twente'], 
        [80, 75, 75, 70], [30, 25, 40, 60], [79, 78, 70, 66]]
columns = ["Position", "Team", "GF", "GA", "Points"]

second_dataframe = pd.DataFrame(data, index=columns)

print("From list: \n {} \n".format(second_dataframe.T)) # the '.T' operator is explained later on

# DataFrame from numpy array
data = np.array([[1, 2, 3, 4], ['PSV','Ajax','Feyenoord','Twente'], 
                 [80, 75, 75, 70], [30, 25, 40, 60], [79, 78, 70, 66]])
columns = ["Position", "Team", "GF", "GA", "Points"]

third_dataframe = pd.DataFrame(data.T, columns=columns)

print("From numpy array: \n {} \n".format(third_dataframe))
# Out:
# From scratch:
#     Position       Team  GF  GA  Points
# 0         1        PSV  80  30      79
# 1         2       Ajax  75  25      78
# 2         3  Feyenoord  75  40      70
# 3         4     Twente  70  60      66
#
# From list:
#    Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66
#
# From numpy array:
#    Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %% [markdown]
# ### DataFrame attributes
# This section gives a quick overview of some of the `pandas.DataFrame` attributes such as `T`, `index`, `columns`, `iloc`, `loc`, `shape` and `values`.

# %%
# transpose the index and columns
print(third_dataframe.T)
# Out:
#             0     1          2       3
# Position    1     2          3       4
# Team      PSV  Ajax  Feyenoord  Twente
# GF         80    75         75      70
# GA         30    25         40      60
# Points     79    78         70      66

# %%
# index makes reference to the row labels
print(third_dataframe.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# columns makes reference to the column labels
print(third_dataframe.columns)
# Out:
# Index(['Position', 'Team', 'GF', 'GA', 'Points'], dtype='object')

# %%
# iloc allows to access the index by integer-location (e.g. all team names, which are in the second columm)
print(third_dataframe.iloc[:,1])
# Out:
# 0          PSV
# 1         Ajax
# 2    Feyenoord
# 3       Twente
# Name: Team, dtype: object

# %%
# loc allows to access the index by label(s)-location (e.g. all team names, which are in the "Team" columm)
print(third_dataframe.loc[0, 'Team'])
# Out:
# PSV

# %%
# shape returns a tuple with the DataFrame dimension, similar to numpy
print(third_dataframe.shape)
# Out:
# (4, 5)

# %%
# values return a Numpy representation of the DataFrame data
print(third_dataframe.values)
# Out:
# [['1' 'PSV' '80' '30' '79']
#  ['2' 'Ajax' '75' '25' '78']
#  ['3' 'Feyenoord' '75' '40' '70']
#  ['4' 'Twente' '70' '60' '66']]

# %% [markdown]
# ### DataFrame methods
# This section gives a quick overview of some of the `pandas.DataFrame` methods such as `head`, `describe`, `concat`, `groupby`,`rename`, `filter`, `drop` and `isna`. To import data from CSV or MS Excel files, we can make use of `read_csv` and `read_excel`, respectively.

# %%
# print the first few rows in your dataset with head()
print(third_dataframe.head()) # In this case, it is not very useful because we don't have thousands of rows
# Out:
#   Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %%
# get the summary statistics of the DataFrame with describe()
print(third_dataframe.describe())
# Out:
#        Position Team  GF  GA Points
# count         4    4   4   4      4
# unique        4    4   3   4      4
# top           1  PSV  75  30     79
# freq          1    1   2   1      1

# %%
# concatenate (join) DataFrame objects using concat()

# first, we will split the above DataFrame in two different ones
df_a = third_dataframe.loc[[0,1],:]
df_b = third_dataframe.loc[[2,3],:]

print(df_a)
print('\n')

print(df_b)
print('\n')

# now, we concatenate both datasets
df = pd.concat([df_a, df_b])

print(df)
# Out:
#   Position  Team  GF  GA Points
# 0        1   PSV  80  30     79
# 1        2  Ajax  75  25     78
#
#
#   Position       Team  GF  GA Points
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66
#
#
#   Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %%
# group the data by certain variable via groupby()
# here, we have grouped the data by goals for, which in this case is 75

group = df.groupby('GF')

print(group.get_group('75'))
# Out:
#   Position       Team  GF  GA Points
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70

# %%
# rename() helps you change the column or index names
print(df.rename(columns={'Position':'Pos','Team':'Club'}))
# Out:
#   Pos       Club  GF  GA Points
# 0   1        PSV  80  30     79
# 1   2       Ajax  75  25     78
# 2   3  Feyenoord  75  40     70
# 3   4     Twente  70  60     66

# %%
# build a subset of rows or columns of your dataset according to labels via filter()
# here, items refer to the variable names: 'Team' and 'Points'; to select columns, we specify axis=1
print(df.filter(items=['Team', 'Points'], axis=1))
# Out:
#         Team Points
# 0        PSV     79
# 1       Ajax     78
# 2  Feyenoord     70
# 3     Twente     66

# %%
# dropping some labels
print(df.drop(columns=['GF', 'GA']))
# Out:
#   Position       Team Points
# 0        1        PSV     79
# 1        2       Ajax     78
# 2        3  Feyenoord     70
# 3        4     Twente     66

# %%
# search for NA (not available) entries in the DataFrame
print(df.isna()) # No NA values
print('\n')

# create a pandas Series with a NA value
# the Series as W (winnin matches)
tmp = pd.Series([np.NaN, 25, 24, 19],  name="W")

# concatenate the Series with the DataFrame
df = pd.concat([df,tmp], axis = 1)
print(df)
print('\n')

# again, check for NA entries
print(df.isna())
# Out:
#    Position   Team     GF     GA  Points
# 0     False  False  False  False   False
# 1     False  False  False  False   False
# 2     False  False  False  False   False
# 3     False  False  False  False   False
#
#
#   Position       Team  GF  GA Points     W
# 0        1        PSV  80  30     79   NaN
# 1        2       Ajax  75  25     78  25.0
# 2        3  Feyenoord  75  40     70  24.0
# 3        4     Twente  70  60     66  19.0
#
#
#    Position   Team     GF     GA  Points      W
# 0     False  False  False  False   False   True
# 1     False  False  False  False   False  False
# 2     False  False  False  False   False  False
# 3     False  False  False  False   False  False

# %% [markdown]
# ## Dataset
#
# For this week exercises we will use a dataset from the Genomics of Drug Sensitivity in Cancer (GDSC) project (https://www.cancerrxgene.org/). In this study (['Iorio et al., Cell, 2016']()), 265 compounds were tested on 1001 cancer cell lines for which different types of -omics data (RNA expression, DNA methylation, Copy Number Alteration, DNA sequencing) are available. This is a valuable resource to look for biomarkers of drugs sensitivity in order to try to understand why cancer patients responds very differently to cancer drugs and find ways to assign the optimal treatment to each patient.
#
# For this exercise we will use a subset of the data, focusing the response to the drug YM155 (Sepantronium bromide) on four cancer types, for a total of 148 cancer cell lines.
#
# | ID          | Cancer type                      |
# |-------------|----------------------------------|
# |   COAD/READ | Colorectal adenocarcinoma        |
# |   NB        | Neuroblastoma                    |
# |   KIRC      | Kidney renal clear cell carcinoma|
# |   BRCA      | Breast carcinoma                 |
#
# We will use the RNA expression data (RMA normalised). Only genes with high variability across cell lines (variance > 5, resulting in 238 genes) have been kept.
#
# Drugs have been tested at different concentration, measuring each time the viability of the cells. Drug sensitivity is measured using the natural log of the fitted IC50 metric, which is defined as the half maximal inhibitory concentration. A lower IC50 corresponds to a more sensitive cell line because a lower amount of drug is sufficient to have a strong response, while a higher IC50 corresponds to a more resistant cell line because more drug is needed for killing the cells.
#
# Based on the IC50 metric, cells can be classified as sensitive or resistant. The classification is done by computing the $z$-score across all cell lines in the GDSC for each drug, and considering as sensitive the ones with $z$-score < 0 and resistant the ones with $z$-score > 0.
#
# The dataset is originally provided as 3 files ([original source](https://www.sciencedirect.com/science/article/pii/S0092867416307462?via%3Dihub)) :
#
# `GDSC_RNA_expression.csv`: gene expression matrix with the cell lines in the rows (148) and the genes in the columns (238).
#
# `GDSC_drug_response.csv`: vector with the cell lines response to the drug YM155 in terms of log(IC50) and as classification in sensitive or resistant.
#
# `GDSC_metadata.csv`: metadata for the 148 cell lines including name, COSMIC ID and tumor type (using the classification from ['The Cancer Genome Atlas TCGA'](https://www.cancer.gov/about-nci/organization/ccg/research/structural-genomics/tcga))
#
# For convenience, we provide the data already curated.
#
# `RNA_expression_curated.csv`: [148 cell lines , 238 genes]
#
# `drug_response_curated.csv`: [148 cell lines , YM155 drug]
#
# The curated data cam be read as `pandas` `DataFrame`s in the following way:

# %%
import pandas as pd

gene_expression = pd.read_csv("./data/RNA_expression_curated.csv", sep=',', header=0, index_col=0)
drug_response = pd.read_csv("./data/drug_response_curated.csv", sep=',', header=0, index_col=0)

# %% [markdown]
# You can use the `DataFrame`s directly as inputs to the the `sklearn` models. The advantage over using `numpy` arrays is that the variable are annotated, i.e. each input and output has a name.

# %% [markdown]
# ## Tools
# The `scikit-learn` library provides the required tools for linear regression/classification and shrinkage, as well as for logistic regression.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Note that the notation used for the hyperparameters in the `scikit-learn` library is different from the one used in the lecture. More specifically, in the lecture $\alpha$ is the tunable parameter to select the compromise between Ridge and Lasso. Whereas, `scikit-learn` library refers to `alpha` as the tunable parameter $\lambda$. Please check the documentation for more details.

# %% [markdown]
# # Exercises
#
# ## Selection of the hyperparameter
#
# Implement cross-validation (using `sklearn.grid_search.GridSearchCV`) to select the `alpha` hyperparameter of `sklearn.linear_model.Lasso`.
#
#
# ## Feature selection
#
# Look at the features selected using the hyperparameter which corresponds to the minimum cross-validation error.
#
# <p><font color='#770a0a'>Is the partition in training and validation sets playing a role in the selection of the hyperparameter? How will this affect the selection of the relevant features?</font></p>
#
# <p><font color='#770a0a'>Should the value of the intercept also be shrunk to zero with Lasso and Ridge regression? Motivate your answer.</font></p>
#
#
# ## Bias-variance
#
# Show the effect of the regularization on the parameter estimates in terms of bias and variance. For this you can repeat the optimization 100 times using bootstrap and visualise the profile of the Lasso regression coefficient over a grid of the hyperparameter, optionally including the variability as error bars.
#
# <p><font color='#770a0a'>Based on the visual analysis of the plot, what are your observation on bias and variance in relation to model complexity? Motivate your answer.</font></p>
#
#
# ## Logistic regression
#
# <p><font color='#770a0a'>Write the expression of the objective function for the penalized logistic regression with $L_1$ and $L_2$ regularisation (as in Elastic net).</font></p>

# %% [markdown]
# Selection of the hyperparameter:

# %%
import sklearn
Lasso_est = Lasso(random_state=0, max_iter=10000)

alpha_vals = np.logspace(-4, 3, 80)
parameter = {'alpha': alpha_vals}

n_folds = 10
gridsearch = sklearn.model_selection.GridSearchCV(Lasso_est, parameter, cv=n_folds, refit=False)

gridsearch.fit(gene_expression, drug_response)

scores = gridsearch.cv_results_["mean_test_score"]
scores_std = gridsearch.cv_results_["std_test_score"]

max_score = np.max(scores)
alpha_index = np.where(scores==max_score)[0][0]
optimal_alpha = alpha_vals[alpha_index]

print("The highest score is :", max_score)
print("The optimal alpha value is :",optimal_alpha)
# Out:
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23966817805012508, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19937051227710692, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21350446690624747, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1972948783574359, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21048525504659535, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24135018454160698, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2593585912678581, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18382424198192587, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21571575034120755, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23219547967520732, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27535828271697355, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25990348544757375, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24366396698865253, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22416807745496656, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21451530970866595, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2750004952384214, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3131682490562643, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21024327668095255, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25986324316477966, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28863777189874174, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.321643380227154, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2995989490672703, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2762184436533232, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24336174947390224, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24701156034714947, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33585989485143153, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35896541454548203, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23364862034688305, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31216507480923705, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32304501847446637, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3843084829592192, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29642888000256923, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3044081404233236, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3322447884427659, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2793755805785272, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38204844020065076, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42172869710682087, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2786378414191876, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3633775508515915, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3698438187724804, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42815162157817577, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3417274346239639, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41822447294500714, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.39004846089441564, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3884756817667153, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41135605284517623, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4321556235504971, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27730863794240224, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38565903836198534, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42666159400336984, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.367538777768712, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4196784341412294, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5399452770865464, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4974858351290219, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3694372701253198, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4681630445516749, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5137295486335625, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34535490253669726, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.37922392463384663, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.46258373502919065, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4229060651126636, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5518994429116352, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5279776944690053, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5765838327441003, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41258917011301377, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44645785473746274, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6335164696008379, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38669433502371436, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4157447299091519, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5093531629959439, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.46180855828516265, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.685107296244375, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43535553780120007, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5787554906153191, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4798708377152885, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4516288312389922, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6494229423820905, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.45201406290183127, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4463370371412841, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5746402670894103, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6382481313523889, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7542104242875716, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5095708684895823, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5860734776884026, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5033117030007404, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.48952143071988247, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7952654000798555, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5501115096231006, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4886808188996477, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5953722190836974, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6236161546636495, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8689522955083389, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5789388682442359, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7243002254447023, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6106064869317407, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5400267408283435, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5981871157283243, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5644604376319199, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34361562869526835, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6520828096189559, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.665316188950728, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.057217399073349, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6276436512162321, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7818467322687785, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8235864704342192, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4670321910373814, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9789019554673655, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6133946309988363, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4299987293574501, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6448298228784153, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7090059103062832, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2912029793958293, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7054318840637441, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0650038004360418, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.017818628991335, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5585071585908198, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9689442400303115, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6948332499848324, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4810665476527112, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8015671381053974, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8048570011948575, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2841802933621211, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6360376680337553, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.342989480935543, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8367312617955488, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7035290612175837, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7606351217151214, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9654070057453124, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5847427300322212, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.597754332776762, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8190431707271785, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2879382057010598, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6993534926004925, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1141405636577826, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0505249804021333, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7135873722141832, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7290074686372389, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7775679963289811, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44183868011349975, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4531416925497174, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.703387143339543, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1020688040225584, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6057678827752365, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8512991432946602, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8133464426735731, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5010286657087275, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8824586893267663, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7928525098034609, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4401884483821454, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6222563473282858, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.679797265811764, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0528412285077031, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7986559747030859, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9326763658308772, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8327078080894581, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2703460039519707, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6560627602399829, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7458853502012562, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23855098902438374, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8888469417124669, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6184340336835216, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.215478868526907, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8363918242672256, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0896387040857891, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6170062520925782, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18496506206904417, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4407079494642484, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5579342182270075, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2310235828237227, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.502253988367583, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.37284496292348807, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7091102228062267, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30717705017047314, tolerance: 0.10049590706766917
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6187020370601615, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3068584978740875, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11246593195192012, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43212490275243143, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.689828108521042, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22682766686305755, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35398816219240925, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3100527956350382, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.50183417694206, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11503768917437668, tolerance: 0.10563151097744361
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3172617856490354, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1938511655913444, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3210789019752337, tolerance: 0.10048336090225564
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2659947189004567, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24800831687377278, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21549703610117166, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35024398383379785, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8772822279538126, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27344382714438065, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13576466058949666, tolerance: 0.10381945563909777
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22148835684103285, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1956118689074524, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21255149729375233, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2779267617831387, tolerance: 0.10098658736842106
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2141087556153276, tolerance: 0.09863845729323309
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4741861881567697, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12011204984355284, tolerance: 0.09532040255639099
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3774664891738182, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11850841472113549, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6131566315319623, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3693766261869116, tolerance: 0.09357541708955223
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13911532843226126, tolerance: 0.10425583582089554
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5919184638779487, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24180505156004184, tolerance: 0.096807332481203
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2017386096949112, tolerance: 0.10098658736842106
#   positive)
# The highest score is : 0.27370762881362487
# The optimal alpha value is : 0.7920164050192549

# %% [markdown]
# Feature Selection

# %%
# Fit a lasso regression using the optimal alpha
optimal_lasso = Lasso(alpha=optimal_alpha, random_state=0, max_iter=1000)
optimal_lasso.fit(gene_expression, drug_response)

# Obtain the coefficients for the fit and select those who have not been shrunk to 0
coefficients = optimal_lasso.coef_
selected_features = np.where(coefficients != 0)[0]

# Print the selected features. 
print('The selected features are:', gene_expression.columns[selected_features])
# Out:
# The selected features are: Index(['GAL', 'ABCB1', 'TSPAN8', 'SELENBP1', 'FABP1', 'TACSTD2', 'AKR1C3'], dtype='object')

# %% [markdown]
# Answer:
#
# Normally the train and validation split plays a crucial role in the selection of the hyperparameter, however to increase the robustness of our model we choose to do cross-validation. This way we see different splits and by averaging their results get a better estimate of the effictiveness of a certain alpha. The alpha parameter in Lasso regression shrinks certain features to zero if they are not significant to the prediction, if we find a different optimal alpha value due to a different train test split this will influence which features are set to zero and thus discarded by the model.
#
# No the intercept should generally not be set to zero since we are using an affine function. The intercept represents the expected value of y if we discard all features or rather set them to 0. If we set the intercept to zero we will introduce bias in the model by forcing this expected value of y to be zero which generally is not a good representation of the data.

# %% [markdown]
# ### Bias Variance

# %%
from sklearn.utils import resample

# Initialize a matrix for saving all coefficients for each bootstrap-alpha_value combination
coefficients_matrix = np.zeros((100, len(alpha_vals), gene_expression.shape[1]))

# Bootstrapping the outer loop by resampling the same dataset
for i in range(100):
    resample_genes, resample_response = resample(gene_expression, drug_response, random_state=i)

    # For each value in alpha for obtain the coefficients for each bootstrap
    for j, alpha in enumerate(alpha_vals):
        
        # Fit the lasso for a certain alpha value
        lasso = Lasso(alpha=alpha)
        lasso.fit(resample_genes, resample_response)
        
        # Obtain and save the coefficients
        bootstrap_alpha_coef = lasso.coef_
        coefficients_matrix[i, j, :] = bootstrap_alpha_coef

coefficients_matrix
# Out:
# (100, 80, 238)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22433259896819874, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2726340663697083, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3181083327737584, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3900075212411899, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43368406902637163, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.476470814134161, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5463736352035239, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6494643739391348, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7769147743308233, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9075780830567236, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0708278137800884, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2354697169778102, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1797125419561705, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7017262976335221, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9904087522216543, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4086377946789517, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.193687150895716, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.546026593402349, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4434761820360182, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.705645883914063, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5651053729856437, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.032238687759819, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.447227455887857, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.1082459980474413, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8192586522409693, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.1597038897018157, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0959819505529045, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1140465383912925, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3926567074242797, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1376866062542312, tolerance: 0.1141714347972973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24366089796212492, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28978161030109806, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3243563654479442, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41194998064934113, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.47212940016838284, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5440585183502809, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6068683790805254, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6723851598716162, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7598513103953297, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8748303146096326, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0168294908651172, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2442331811606022, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3427620253068158, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.321426964110942, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5390657902069187, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8636005268771019, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4596719895582726, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6819176141604948, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3352233234195114, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.341824324057586, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1880972729850203, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.357828908733623, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3029023414722625, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.6639291590701397, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8196921484421973, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.33262687850823, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6313146040431743, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6074369498342023, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14458650755818603, tolerance: 0.10544104432432433
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19079482764783476, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22332132215614534, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2690500520355378, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30675638707481795, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.333868640021495, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38206114596604746, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5057472486934048, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5435837611532798, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6754926334464894, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8043882460058035, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9132955392223862, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9868841348564148, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.174924386321732, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3202467227199177, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3656944068590422, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8218700563726185, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8306396414042059, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7822885292442923, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1418060190078987, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.985046891791941, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5824910930272096, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7607553956444977, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9000112535384583, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2426058581642656, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.494975392343591, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.8120790097258888, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.7087677894568465, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6063957273904403, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.200422181426818, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3515875778591635, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4165357418211677, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21220761623191464, tolerance: 0.08715052074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23552534576732911, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27174386373663745, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32724656110753336, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3932721193625719, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.456009004415263, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.549239773783167, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5933178269103969, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6811953400135342, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7570140614354807, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9204658210023993, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9571329445535889, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1469869402857926, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.398051919056696, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4903831855405718, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.549775398892217, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7458412135372137, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6946571277289315, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1802074419924953, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7825187702944252, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1020236410909825, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.81988814480716, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0057805437722216, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.651511751877026, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3627063019468495, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.689467453432111, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1715535358099816, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8167859953582841, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.852100855773303, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33236249314362887, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3181524361234125, tolerance: 0.09605163972972974
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2355351492476051, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.278664416115641, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3224924190416021, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3787602762043231, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4322190176025369, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4723610746064972, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.637239285178046, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7254383528307156, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8900212987438558, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9133631193034097, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9342301667868805, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1375180278658794, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4077347249911498, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6817616984034847, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0337320596169604, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3060011246286054, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.6735889909711865, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0025734054764297, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.328498848783503, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.188144089291695, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.334114156601117, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8856802109931006, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.085898467711967, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.638606994474026, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9438634888359525, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3876605888762885, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9635552711912077, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3400660239478057, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4237101123918503, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.026703678140988, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.498505300150395, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5460333617861721, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.159624947662536, tolerance: 0.09739672452702704
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3305577552038269, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.40095626384516264, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.47479660539553364, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5784593162394925, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6747370256506807, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7833172086669924, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8644695259095845, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0226111616810003, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2357014263397303, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4247542969116442, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4728137318382588, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5955632338734076, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7719792484853985, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.032944683355765, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.029050760516088, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2360551546020204, tolerance: 0.125079310472973
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.8078979247584828, tolerance: 0.125079310472973
#   positive)
# ...
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5214880129873654, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6226283286362077, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7173878530702092, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8509979650450217, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9004786446758335, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.09855986992492, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3816228194209146, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5495649528130944, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5815064576398679, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7307385717972747, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1612382849505325, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.6702945313792035, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.66943816644674, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.796623262807701, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.244844339820277, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.7422943552312073, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.483688953005229, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.479786123158596, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.855182930246144, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.92786087823276, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.776317996035436, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.206141417070741, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.628125925553017, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.1622454727414304, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3771169693056287, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.932459089881899, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1730771445157089, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5190917056807507, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33358150463345737, tolerance: 0.10907976074324324
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19108941005803567, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22222614464654852, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2544763381731479, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3014437634427503, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3628372450911487, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41247263831888037, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4785091830613596, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5827228817144332, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6884038605764767, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8038436097108542, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9035571914939196, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0904387935495994, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1302495606012384, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.192801913897306, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2055711951466805, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3759474619448842, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6387302030621727, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4940016500441278, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4138571128151383, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2472260878804176, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8406644296290253, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7228852167329778, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5604760005898028, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3294588575930666, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7706666964147244, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5357651740755438, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.47376570263457385, tolerance: 0.10447032081081081
#   positive)
# c:\Users\mathi\anaconda3\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24041269252144382, tolerance: 0.10447032081081081
#   positive)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# ##### Answer
# The expression for the objective of elastic net in logistic regression is:
#
# $L(\beta) = -(\frac{1}{n} * \sum _{i=1}^n[y_i * log(p_i) + (1- y_i)*log(1-p_i)]) + \alpha * (\frac{1-\rho}{2}\sum^p_{j=1} \beta _j^2 + \rho \sum ^p _{j=1}|\beta _j|) $
#
# Here the expression consists of two main parts, the objective function and the elastic net regularization:
#
# The objective function consists of a sum over all samples where we take the average of n samples over two parts:
#
# The left part 'activates' when the true label is 1 and equates the log of p_i which is the prediction of the logistic regression ($p_i=\frac{1}{1+exp(X_i\beta)}$)
#
# The right part represents the probability of log(1-p_i) only when the true lable is 0
#
# Then we have the regularization part of the elastic net formula:
#
# We have two hyperparamters which are alpha corresponding the strength of the regularization and a new hyperparameter rho representing the ratio between L1 and L2 regularization.
#
# Then again we have a left part representing L2 regularization in beta squared which helps against large coefficients reducing overfitting.
#
# And we have right part representing L1 regularization shrinking small coefficients
